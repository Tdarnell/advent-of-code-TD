# %% [markdown]
# # Day 02

# %%
11 / 2
# Out:
# 5.5

# %%
input_str: str = "11-22,95-115,998-1012,1188511880-1188511890,222220-222224,1698522-1698528,446443-446449,38593856-38593862,565653-565659,824824821-824824827,2121212118-2121212124"
input_ranges = input_str.split(",")
for i, rng in enumerate(input_ranges):
    start, end = rng.split("-")
    for num in range(int(start), int(end) + 1):
        ns = str(num)
        if ns[: len(ns) // 2] == ns[len(ns) // 2 :]:
            print(f"{ns} is a repeating pattern")
# Out:
# 11 is a repeating pattern
# 22 is a repeating pattern
# 99 is a repeating pattern
# 1010 is a repeating pattern
# 1188511885 is a repeating pattern
# 222222 is a repeating pattern
# 446446 is a repeating pattern
# 38593859 is a repeating pattern

# %%
2121212121 / len("2121212121")
# 11 / len("11")
# 22 / len("22")
13 / len("13")
123123123 / 123
# Out:
# 1001001.0

# %%
for num in [
    11,
    22,
    99,
    111,
    999,
    1010,
    1188511885,
    222222,
    446446,
    38593859,
    565656,
    824824824,
    2121212121,
]:
    ns_len = len(str(num))
    possible_blocks = [k for k in range(1, (ns_len // 2) + 1) if (ns_len % k == 0)]
    for block in possible_blocks:
        S = (10**ns_len - 1) // (10**block - 1)
        if num % S == 0:
            print(num)
            break
# Out:
# 11
# 22
# 99
# 111
# 999
# 1010
# 1188511885
# 222222
# 446446
# 38593859
# 565656
# 824824824
# 2121212121

# %% [markdown]
# # Day 03

# %%
import math


def extract_digits(num: int) -> list[int]:
    if num == 0:
        return [0]
    # Source - https://stackoverflow.com/a
    # Posted by inspectorG4dget, modified by community. See post 'Timeline' for change history
    # Retrieved 2025-12-05, License - CC BY-SA 4.0
    return [(num // (10**i)) % 10 for i in range(math.ceil(math.log(num, 10)), -1, -1)][
        bool(math.log(num, 10) % 1) :
    ]


def find_joltage(digits: list[int]):
    if not digits:
        return 0
    if not isinstance(digits, list):
        raise ValueError("Input to find_joltage must be a list of integers.")
    if not all(isinstance(d, int) for d in digits):
        raise ValueError("All elements in the input list must be integers.")
    max1 = max(digits[:-1])
    max_idx = digits.index(max1)
    max2 = max(digits[max_idx + 1 :])
    max2_idx = digits[max_idx + 1 :].index(max2) + (max_idx + 1)
    if max_idx > max2_idx:
        return max2 * 10 + max1
    return max1 * 10 + max2


inputs = ["987654321111111", "811111111111119", "234234234234278", "818181911112111"]
for i in inputs:
    input_digits = [int(_) for _ in i]
    print(find_joltage(input_digits))
# Out:
# 98
# 89
# 78
# 92

# %%
def find_joltage(digits: list[int], num_maxs=2):
    if not digits:
        return 0
    if not isinstance(digits, list):
        raise ValueError("Input to find_joltage must be a list of integers.")
    if not all(isinstance(d, int) for d in digits):
        raise ValueError("All elements in the input list must be integers.")
    output = 0
    current_slice_start = 0
    for m in range(num_maxs):
        current_slice_end = len(digits) - (num_maxs - (m + 1))
        slice_digits = digits[current_slice_start:current_slice_end]
        next_digit = max(slice_digits)
        current_slice_start = slice_digits.index(next_digit) + current_slice_start + 1
        output = output * 10 + next_digit
    return output


inputs = ["987654321111111", "811111111111119", "234234234234278", "818181911112111"]
for i in inputs:
    input_digits = [int(_) for _ in i]
    print(find_joltage(input_digits, 12))
# Out:
# 987654321111
# 811111111119
# 434234234278
# 888911112111

# %% [markdown]
# # Day 04

# %%
input_str = """..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@."""
answer = 13
answer_str = """..xx.xx@x.
x@@.@.@.@@
@@@@@.x.@@
@.@@@@..@.
x@.@@@@.@x
.@@@@@@@.@
.@.@.@.@@@
x.@@@.@@@@
.@@@@@@@@.
x.x.@@@.x."""

# first I am going to for loop the ... out of this
rows = input_str.splitlines()
# assiming all are identical, which I think they must be
row_len = len(rows[0])
accessible = []
for row_number in range(len(rows)):
    current_row = rows[row_number]
    prev_row = rows[row_number - 1] if row_number > 0 else None
    next_row = rows[row_number + 1] if row_number + 1 < len(rows) else None
    for col_number in range(row_len):
        if current_row[col_number] != "@":
            continue
        adjacent_idxs = [
            col_number + i for i in [-1, 0, 1] if 0 <= col_number + i < row_len
        ]
        # print(adjacent_idxs)
        values = [current_row[col_number - 1]] if col_number > 0 else []
        values += (
            [current_row[col_number + 1]]
            if col_number + 1 < row_len
            else []
        )
        if prev_row:
            values += [
                val for val in prev_row[adjacent_idxs[0] : adjacent_idxs[-1] + 1]
            ]
        if next_row:
            values += [
                val for val in next_row[adjacent_idxs[0] : adjacent_idxs[-1] + 1]
            ]
        count = values.count("@")
        # print the state at row 4 last column
        if row_number == 4 and col_number == row_len - 1:
            print("Debug info for row 4, column " + str(col_number))
            print("Current cell value:", current_row[col_number])
            print("Current Row:", current_row)
            print("Prev Row:", prev_row)
            print("Next Row:", next_row)
            print("Adjacent Idxs:", adjacent_idxs)
            print("Values:", values)
            print("Count:", count)
        if count < 4:
            accessible.append((row_number, col_number))
print(len(accessible))
accessible_str = ""
for row_number in range(len(rows)):
    for col_number in range(row_len):
        if (row_number, col_number) in accessible:
            accessible_str += "x"
        else:
            accessible_str += rows[row_number][col_number]
    accessible_str += "\n"
print(accessible_str)
# Out:
# Debug info for row 4, column 9
# Current cell value: @
# Current Row: @@.@@@@.@@
# Prev Row: @.@@@@..@.
# Next Row: .@@@@@@@.@
# Adjacent Idxs: [8, 9]
# Values: ['@', '@', '.', '.', '@']
# Count: 3
# 13
# ..xx.xx@x.
# x@@.@.@.@@
# @@@@@.x.@@
# @.@@@@..@.
# x@.@@@@.@x
# .@@@@@@@.@
# .@.@.@.@@@
# x.@@@.@@@@
# .@@@@@@@@.
# x.x.@@@.x.

# %%
input_str = """..@@.@@@@.
@@@.@.@.@@
@@@@@.@.@@
@.@@@@..@.
@@.@@@@.@@
.@@@@@@@.@
.@.@.@.@@@
@.@@@.@@@@
.@@@@@@@@.
@.@.@@@.@."""
answer = 43

rows = input_str.splitlines()
row_len = len(rows[0])
accessible = []
changes_last_iter = row_len * len(rows)
while changes_last_iter != 0:
    changes_this_iter = 0
    for row_number in range(len(rows)):
        current_row = rows[row_number]
        prev_row = rows[row_number - 1] if row_number > 0 else None
        next_row = rows[row_number + 1] if row_number + 1 < len(rows) else None
        for col_number in range(row_len):
            if current_row[col_number] != "@":
                continue
            adjacent_idxs = [
                col_number + i for i in [-1, 0, 1] if 0 <= col_number + i < row_len
            ]
            values = [current_row[col_number - 1]] if col_number > 0 else []
            values += (
                [current_row[col_number + 1]]
                if col_number + 1 < row_len
                else []
            )
            if prev_row:
                values += [
                    val for val in prev_row[adjacent_idxs[0] : adjacent_idxs[-1] + 1]
                ]
            if next_row:
                values += [
                    val for val in next_row[adjacent_idxs[0] : adjacent_idxs[-1] + 1]
                ]
            count = values.count("@")
            if count < 4:
                # I made the mistake of removing the rolls of paper at this stage,
                # resulting in far too many being removed as it freed them up mid iteration
                accessible.append((row_number, col_number))
                changes_this_iter += 1
    changes_last_iter = changes_this_iter
    for accessed in accessible[-changes_this_iter:]:
        row_number, col_number = accessed
        current_row = rows[row_number]
        rows[row_number] = (
            current_row[:col_number] + "." + current_row[col_number + 1 :]
        )
    print(f"Removed {changes_this_iter} accessible '@' this iteration.")
print(len(accessible))
# Out:
# Removed 13 accessible '@' this iteration.
# Removed 12 accessible '@' this iteration.
# Removed 7 accessible '@' this iteration.
# Removed 5 accessible '@' this iteration.
# Removed 2 accessible '@' this iteration.
# Removed 1 accessible '@' this iteration.
# Removed 1 accessible '@' this iteration.
# Removed 1 accessible '@' this iteration.
# Removed 1 accessible '@' this iteration.
# Removed 0 accessible '@' this iteration.
# 43

# %% [markdown]
# # Day 05

# %%
import re


input_str = """3-5
10-14
16-20
12-18

1
5
8
11
17
32"""
fresh_range, to_check = input_str.split("\n\n")
print(fresh_range)
print(to_check)
fresh_stop_starts = [list(map(int, re.findall(r'\d+', line))) for line in fresh_range.splitlines()]
fresh_idx = [num for start, stop in fresh_stop_starts for num in range(start, stop + 1)]
print(fresh_stop_starts)
print(fresh_idx)
fresh_count = 0
for idx in to_check.splitlines():
    if int(idx) in fresh_idx:
        fresh_count += 1
print(fresh_count)
# Out:
# 3-5
# 10-14
# 16-20
# 12-18
# 1
# 5
# 8
# 11
# 17
# 32
# [[3, 5], [10, 14], [16, 20], [12, 18]]
# [3, 4, 5, 10, 11, 12, 13, 14, 16, 17, 18, 19, 20, 12, 13, 14, 15, 16, 17, 18]
# 3

# %% [markdown]
# # Day 06

# %%
import re
input_str = "123 328  51 64 \n 45 64  387 23 \n  6 98  215 314\n*   +   *   +  "
rows = input_str.splitlines()
operators = rows[-1].replace(" ", "")
# match numbers split by whitespace
rows_num = [
    re.findall(r'\d+', row) for row in rows[:-1]
]
answer = 0
for col in range(len(operators)):
    digits = [int(rows_num[row][col]) for row in range(len(rows_num))]
    if operators[col] == "+":
        col_result = sum(digits)
    elif operators[col] == "*":
        col_result = 1
        for d in digits:
            col_result *= d
    answer += col_result
print(answer)
# Out:
# 4277556

# %%
import re
input_str = "123 328  51 64 \n 45 64  387 23 \n  6 98  215 314\n*   +   *   +  "
rows = input_str.splitlines()
operators = rows[-1].replace(" ", "")
# wow the expected way to read this next part is horrible
# took me a while to even get my head around what they were trying to explain
# I still think use regext to extract first
rows_num = [
    re.findall(r'\d+', row) for row in rows[:-1]
]
columns_len = len(operators)
# transpose into columns
columns = [
    [rows_num[row][col] for row in range(len(rows_num))]
    for col in range(columns_len)
]
print(columns)
answer = 0
for j,column in enumerate(columns):
    # now I need to loop through each significant digit until the longest string in
    # the column
    max_len = max([len(c) for c in column])
    column_nums = []
    # pad every number suffixed with 0's up to the max_len
    padded_column: list[str] = [str(c).ljust(max_len, "x") for c in column]
    print(padded_column)
    # loop backwards
    for i in range(max_len, 0, -1):
        digit = "".join([c[i-1] for c in padded_column]).replace("x", "")
        column_nums.append(int(digit))
    print(column_nums)
    # perform the operator on the extracted column
    if operators[j] == "+":
        col_result = sum(column_nums)
    elif operators[j] == "*":
        col_result = 1
        for d in column_nums:
            col_result *= d
    print(col_result)
    answer += col_result
print(answer)

# I realised since I have stripped the numbers already this is flawed
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 14
#      11 columns_len = len(operators)
#      12 # transpose into columns
#      13 columns = [
# ---> 14     [rows_num[row][col] for row in range(len(rows_num))]
#      15     for col in range(columns_len)
#      16 ]
#      17 print(columns)
#      18 answer = 0
#
# IndexError: list index out of range

# %%
input_str = "123 328  51 64 \n 45 64  387 23 \n  6 98  215 314\n*   +   *   +  "
rows = input_str.splitlines()
operators = rows[-1].replace(" ", "")
len(rows[0]) / rows[0].count(" ")
len(rows[-1]) - rows[-1].count(" ") # 4 columns
# As the columns are whitespace seperated the number of columns should match
# the length of each string column I think ... lets test

operators = "*   +  +    *   +  +    +  *   *   *   +   *   +    *  *   +  +  *  +    +  +   *   +   *   +   +   *   *   *  +   *  *  +    +   *  +    +    +  *  +   *   +  +   +   *  *  *  *   +  +    *   *   *  *   *  +   +  *   +  *   +    +  +    +  *  *   +    *  *   *  +   +   +  +   +    +   +    +  +    +  *  +   *  *  *  *  +    *  +    *   +    +  +   +    *   +    *  +  +  +    *   +    *  +  +   +   *  *   *   +    *   *  *   *  +    +  +  +  *  *  +   +    *  +  *  +    *   +  +   +  +   *   +   +    *  +    *  +   *   *   *   *  *   *  *  +  *  +    +  +    +  *  *  +    +  *   *  +   *   +    *  +   +    +   +    *  +  *  +  *  +  *  +   *  *  +  *   +    +   +    +  +  +    *  *  *   *  *   *   +    +   *  *   +    *   *  *   +   +   *  *  *  *   +  *   *  +  +   +  +   *  +  +  +    *   +  +    +    *   *   +    *   *  *  *  *   +    *  *  +   *  *   *  *   +  *   *  *   +  +   +    +  +    +   +    +    *   *   +   *  +   +    *   *   +  +   *   *   *   *   +    *   *   +  +    +   +   +    +    *  +   *  *   *  +   *   *  +   *  *  +   *   *   *   *   +  +   *  +  *  +   +  +  *  *  *  +  +  +    +   *  +    *   *   *  *  +   +    +    +   *   *   +    +    *   *   *  *   *   *  *  *  *   +   +   *   *  +  *  +   +    *   *   *   *   *   *  +   *  *  +    +   +   *   *   *  +   *   *   *  +   +    *  +  *   *   *  +  *  *  +   *  *  +    +    *   +   *   *  *  +  +    +  +  +   *  +   +    +  *  *   +   *   *  *   *  *   +  +  +    +    *  *  *  +  +    *  +   *   *   *   *   *   +    *  +   +    +    +  +  *  *  +  *   *  *  *  +    *  *   *   +    +   *   +  +   +    +   +   *  +  *  *   +   +   *   +  *   +   +  +   *  *   *   *  +  *  *   *  *   *   *  *  +    +   +  *   *  +   *   +   *  +    *   +  *   +  *  *  +  +    *  +    +  *   *   +    +   +  *   *  +   *  +    *  *  *   *   *   *  *  *  *  +    *  +   +    *   +   *   +    *  *  *   +  +   *   *   *  +    +  +  +   +   +   +    *   +   *  *  *   *  *  +    *   *  *  +  +  +   +    *   +    *  +   +   +  +   +   *   +   *  *   +   *  *  *   *  *  *  *   +   +  +  +   *  +   *  *   +    *   *  +  +   *   *   +    *   *  +   +   +   *   +  *  *   *   *   *   *   +   +   +  +  *  +   *   +    +  *   *  +   *   *  +   +    +   +    *   +   +   *   *   +   *   +    +   +    +    *   +    *   *   *   +   +   +  +  *  +  *   +  +  *  *   +    +    +    +   +    *  *   +   +    *  *  *   *   +   +  +  *  +   +    +   +  +   *   *  +  +    *   +  +  +  +   *  +  *  +   *   *  *  +  +  +   *  +  +  *   +   +  *  *  +   *  *  *  *   *   *  +   *   +  *   +  +    *   *   +   *  *  +    *   +   +   +   +    *   +    +  +   *   *  +    +   *   +   *  *  +    *   *  +    +    *  *   +    *  +    *  *  +    +    +  +  *  *  +   *  *   *  *  *   +  +  *   +    +    +  +  *  +   *   *  +   *  *  *   +   *  *  *   *  *  *  *   *  +    *   *   *  +  *   +  +   +  +    *  +  +   +   *  +  +    +  *  +  *   +  +  +    +   *   *  +  +   +    *   *  +   +    *   +   +  *   +  +  +  *  *  +   +    +  +  *  +   *  *   +   +   +  *   +    +    *   *  +    *  +  +  +  *  *   *  *   *   *  *  +  *  +   *   +    +    *   +    *  +   *   *   +    +  *   *  *   +    *   *   *  *   *  *  *  *   *  *  *  *   +   +   *  *   +    *  +  *  *   +  *   *   *  +  *  *   +  +   *   *  +   +    +  +  +   *  +    +  +   *  *  *  *  *   +   +    +  +    *   +   +    *   +   *   *  +   *   +   *  +  +   *   +   *   *  *   +    +  *   +  +   +  *   *  *  +    +  +  *   *  +   *  *   +   +    +   *  +  +    *  +    +    +    +    *  +    +   +    *   +   *  +   +  *  *   +   *  *  *   *  +   *  +    *   *   +   *  *  *   *   *  *   +  *  *   +  *   *  *  +    +    +   *  +    +    +   +    +  +   *   *   +  +   *   +    *   *  +    *   +    * "

len(operators) - operators.count(" ") # 1000
# ... nope poor assumption, however ...
(len(operators)) / 1000
# ok they are not equal spaced, I need to build an index width or come up with something better
# Out:
# 2734

# %%
import re
input_str = "123 328  51 64 44\n 45 64  387 23 67\n  6 98  215 314 1\n*   +   *   +  * "
rows = input_str.splitlines()
operators = rows.pop(-1)
# I realised I can just iterate over the operators row and use
# that to determine my columns ...
current_operator = operators[0]
current_digits = []
answer = 0
for idx,operator in enumerate(operators):
    if (operator != " " and idx != 0):
        if current_operator == "+":
            col_result = sum(current_digits)
        elif current_operator == "*":
            col_result = 1
            for d in current_digits:
                col_result *= d
        # print(col_result)
        answer += col_result
        print(f"Processed column with operator '{current_operator}': {current_digits} => {col_result}")
        current_operator = operator
        current_digits = []
    digit = ""
    for row_idx,row in enumerate(rows):
        digit += row[idx]
    if digit.strip() == "":
        continue
    digit_int = int(digit.strip())
    current_digits.append(digit_int)
# process last column
if current_operator == "+":
    col_result = sum(current_digits)
elif current_operator == "*":
    col_result = 1
    for d in current_digits:
        col_result *= d
answer += col_result
print(f"Processed column with operator '{current_operator}': {current_digits} => {col_result}")

print(answer)
# Out:
# Processed column with operator '*': [1, 24, 356] => 8544
# Processed column with operator '+': [369, 248, 8] => 625
# Processed column with operator '*': [32, 581, 175] => 3253600
# Processed column with operator '+': [623, 431, 4] => 1058
# Processed column with operator '*': [46, 471] => 21666
# 3285493
